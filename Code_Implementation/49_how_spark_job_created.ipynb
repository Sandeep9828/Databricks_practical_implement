# %%
df = spark.read.option('header',True).option('inferSchema',True).format('csv').load('/Volumes/workspace/adhoc/customer')




'''
for large data instead of infering the scheme we should define the schema it help to reduce no of job created while reading the data here 2 job will be create, first is reading the data and second is for the infer the schema.
'''
