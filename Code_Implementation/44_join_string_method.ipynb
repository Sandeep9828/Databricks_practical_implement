# %%
lst = ['sandeep','singh','shekhawat']

st = ' '.join(lst)

print(st)

# %%
df = spark.createDataFrame([(1,'sandeep','20-11-2025',5,55000)],['employee_id', 'Name', 'doj', 'employee_dept_id', 'salary'])

df.display()

# %%
cols = df.columns

st = ','.join(cols)

syntax = f''' select {st} from df'''

print(syntax)

# %%
joinString = ' AND '.join(list(map(lambda x: "Target."+x +" = Source."+x,cols)))

print(joinString)

# %%
lst = [3,5,7]

",".join(map(str,lst))
